# %%
import pandas as pd
from os import listdir
from os.path import isfile, join
from multiprocessing import Pool
from tqdm import tqdm
import pickle
from datetime import datetime
from datetime import timedelta
import numpy as np
from matplotlib import pyplot as plt
from collections import Counter
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix

# %%
data_path = '/Users/ruoyangzhang/Documents/PythonWorkingDirectory/Eleven_super_case_customer_insights_Data/'

# %%
all_log_files = [f for f in listdir(data_path) if isfile(join(data_path, f)) and f[:8] == 'log_file']

# %%
for file in all_log_files:
    pd.read_csv(data_path+all_log_files[0])
    log_file.index = log_file.unique_visitor_session
    unique_sessions = list(set(log_file.index))
    fields_unique_val = [ele for ele in list(log_file.columns) if ele not in ['EVENT_DATE', 'PAGES']]
# Out:
# ['log_file_all_purchases_2017-12.csv',
#  'log_file_all_purchases_2017-10.csv',
#  'log_file_all_purchases_2017-11.csv',
#  'log_file_all_purchases_2017-08.csv',
#  'log_file_all_purchases_2017-09.csv',
#  'log_file_all_purchases_2018-01.csv',
#  'log_file_all_purchases_2018-03.csv',
#  'log_file_all_purchases_2018-02.csv']

# %%
pd.read_csv(data_path+all_log_files[0])
# Out:
#         Unnamed: 0  VISITOR_ID CONNECTED_SESSION  ID_SESSION  \
# 0                0      658106               OUI          27
# 1                1      658106               OUI          27
# 2                2      658106               OUI          27
# 3                3      658106               OUI          27
# 4                4      658106               OUI          27
# 5                5      658106               OUI          27
# 6                6      658106               OUI          27
# 7                7      658106               OUI          27
# 8                8      658106               OUI          27
# 9                9      658106               OUI          27
# 10              10      658106               OUI          27
# 11              11      658106               OUI          27
# 12              12      658106               OUI          27
# 13              13      658106               OUI          27
# 14              14      658106               OUI          27
# 15              15      658106               OUI          27
# 16              16      658106               OUI          27
# 17              17      658106               OUI          27
# 18              18      658106               OUI          27
# 19              19      658106               OUI          27
# 20              20      658106               OUI          27
# 21              21      490490               OUI          49
# 22              22      490490               OUI          49
# 23              23      490490               OUI          49
# 24              24      490490               OUI          49
# 25              25      490490               OUI          49
# 26              26      490490               OUI          49
# 27              27      490490               OUI          49
# 28              28      490490               OUI          49
# 29              29      490490               OUI          49
# ...            ...         ...               ...         ...
# 928395      928395      762335               OUI       21203
# 928396      928396      762335               OUI       21203
# 928397      928397      762335               OUI       21203
# 928398      928398      762335               OUI       21203
# 928399      928399      762335               OUI       21203
# 928400      928400      762335               OUI       21203
# 928401      928401      762335               OUI       21203
# 928402      928402      329009               OUI       21925
# 928403      928403      329009               OUI       21925
# 928404      928404      329009               OUI       21925
# 928405      928405      329009               OUI       21925
# 928406      928406      329009               OUI       21925
# 928407      928407      329009               OUI       21925
# 928408      928408      329009               OUI       21925
# 928409      928409      329009               OUI       21925
# 928410      928410      329009               OUI       21925
# 928411      928411      329009               OUI       21925
# 928412      928412      329009               OUI       21925
# 928413      928413      329009               OUI       21925
# 928414      928414      329009               OUI       21925
# 928415      928415      329009               OUI       21925
# 928416      928416      329009               OUI       21925
# 928417      928417      329009               OUI       21925
# 928418      928418      329009               OUI       21925
# 928419      928419      329009               OUI       21925
# 928420      928420      329009               OUI       21925
# 928421      928421      329009               OUI       21925
# 928414  2017-12-31 23:37:53  2017-12-31 23:39:07
# 928415  2017-12-31 23:37:53  2017-12-31 23:44:11
# 928416  2017-12-31 23:37:53  2017-12-31 23:51:17
# 928417  2017-12-31 23:37:53  2017-12-31 23:51:38
# 928418  2017-12-31 23:37:53  2017-12-31 23:44:16
# 928419  2017-12-31 23:37:53  2017-12-31 23:37:59
# 928420  2017-12-31 23:37:53  2017-12-31 23:38:53
# 928421  2017-12-31 23:37:53  2017-12-31 23:47:47
# 928422  2017-12-31 23:37:53  2017-12-31 23:39:11
# 928423  2017-12-31 23:37:53  2017-12-31 23:37:53
# 928424  2017-12-31 23:37:53  2017-12-31 23:38:56
#
#                                                     PAGES GLOBAL_SOURCES  \
# 0                                              mon panier   Accès Direct
# 1                                              mon panier   Accès Direct
# 2                                              mon panier   Accès Direct
# 3                                              mon panier   Accès Direct
# 4                                        mes informations   Accès Direct
# 5                                        mes informations   Accès Direct
# 6                                                 accueil   Accès Direct
# 7                                         ajout au panier   Accès Direct
# 8       category 1::category 1 uni::accueil category 1...   Accès Direct
# 9       category 1::category 1 uni::accueil category 1...   Accès Direct
# 10      category 1::sous_category_-3503180197758226074...   Accès Direct
# 11      category 1::sous_category_-3503180197758226074...   Accès Direct
# 12      category 1::sous_category_-3503180197758226074...   Accès Direct
# 13      category 1::category 1 uni::fiche produit::-47...   Accès Direct
# 14                                           ma livraison   Accès Direct
# 15                                           ma livraison   Accès Direct
# 16                                           ma livraison   Accès Direct
# 17                            commander/recapitulatif.htm   Accès Direct
# 18                            commander/recapitulatif.htm   Accès Direct
# 19                                           mon paiement   Accès Direct
# 20                                confirmation d achat cb   Accès Direct
# 21                                             mon panier   Accès Direct
# 22                                             mon panier   Accès Direct
# 23                                             mon panier   Accès Direct
# 24                                             mon panier   Accès Direct
# 25                                       mes informations   Accès Direct
# 26                                                accueil   Accès Direct
# 27                                           ma livraison   Accès Direct
# 28                                           ma livraison   Accès Direct
# 29                            commander/recapitulatif.htm   Accès Direct
# ...                                                   ...            ...
# 928395  category 11::category 11 naturelles::fiche pro...        Moteurs
# 928396  category 11::category 11 naturelles::fiche pro...        Moteurs
# 928397  category 11::category 11 naturelles::fiche pro...        Moteurs
# 928398  category 25::category 32 lits impermeables::ac...        Moteurs
# 928399  category 16::sous_category_286518012525378294:...        Moteurs
# 928400                        confirmation d achat cheque        Moteurs
# 928401  category 25::category 32 lits impermeables::fi...        Moteurs
# 928402                                         mon panier   Accès Direct
# 928403                                         mon panier   Accès Direct
# 928404                                         mon panier   Accès Direct
# 928405                                         mon panier   Accès Direct
# 928406                                            accueil   Accès Direct
# 928407                                            accueil   Accès Direct
# 928408                                    ajout au panier   Accès Direct
# 928409                                    ajout au panier   Accès Direct
# 928410                                       ma livraison   Accès Direct
# 928411                                       ma livraison   Accès Direct
# 928412                        commander/recapitulatif.htm   Accès Direct
# 928413                                       mon paiement   Accès Direct
# 928414                         accueil la maison pratique   Accès Direct
# 928415                               mon compte ::accueil   Accès Direct
# 928416                               mon compte ::accueil   Accès Direct
# 928417  mon compte ::parametres de mon compte::gerer m...   Accès Direct
# 928418  mon compte ::parametres de mon compte::mon pro...   Accès Direct
# 928419  category 1::category 1 fantaisie::fiche produi...   Accès Direct
# 928420  category 1::category 1 fantaisie::fiche produi...   Accès Direct
# 928421                        confirmation d achat cheque   Accès Direct
# 928422     category 17::fiche produit::312894743965777571   Accès Direct
# 928423                                        fidelissime   Accès Direct
# 928424                                        fidelissime   Accès Direct
#
#        DEVICE_TYPE DEVICE_MODEL  LOADINGS  unique_visitor_session
# 0       Ordinateur          NaN         1                65810627
# 1       Ordinateur          NaN         1                65810627
# 2       Ordinateur          NaN         1                65810627
# 3       Ordinateur          NaN         1                65810627
# 4       Ordinateur          NaN         1                65810627
# 5       Ordinateur          NaN         1                65810627
# 6       Ordinateur          NaN         1                65810627
# 7       Ordinateur          NaN         1                65810627
# 8       Ordinateur          NaN         1                65810627
# 9       Ordinateur          NaN         1                65810627
# 10      Ordinateur          NaN         1                65810627
# 11      Ordinateur          NaN         1                65810627
# 12      Ordinateur          NaN         1                65810627
# 13      Ordinateur          NaN         1                65810627
# 14      Ordinateur          NaN         1                65810627
# 15      Ordinateur          NaN         1                65810627
# 16      Ordinateur          NaN         1                65810627
# 17      Ordinateur          NaN         1                65810627
# 18      Ordinateur          NaN         1                65810627
# 19      Ordinateur          NaN         1                65810627
# 20      Ordinateur          NaN         1                65810627
# 21      Ordinateur          NaN         1                49049049
# 22      Ordinateur          NaN         1                49049049
# 23      Ordinateur          NaN         1                49049049
# 24      Ordinateur          NaN         1                49049049
# 25      Ordinateur          NaN         1                49049049
# 26      Ordinateur          NaN         1                49049049
# 27      Ordinateur          NaN         1                49049049
# 28      Ordinateur          NaN         1                49049049
# 29      Ordinateur          NaN         1                49049049
# ...            ...          ...       ...                     ...
# 928395    Tablette         iPad         1             76233521203
# 928396    Tablette         iPad         1             76233521203
# 928397    Tablette         iPad         1             76233521203
# 928398    Tablette         iPad         1             76233521203
# 928399    Tablette         iPad         1             76233521203
# 928400    Tablette         iPad         1             76233521203
# 928401    Tablette         iPad         1             76233521203
# 928402  Ordinateur          NaN         1             32900921925
# 928403  Ordinateur          NaN         1             32900921925
# 928404  Ordinateur          NaN         1             32900921925
# 928405  Ordinateur          NaN         1             32900921925
# 928406  Ordinateur          NaN         1             32900921925
# 928407  Ordinateur          NaN         1             32900921925
# 928408  Ordinateur          NaN         1             32900921925
# 928409  Ordinateur          NaN         1             32900921925
# 928410  Ordinateur          NaN         1             32900921925
# 928411  Ordinateur          NaN         1             32900921925
# 928412  Ordinateur          NaN         1             32900921925
# 928413  Ordinateur          NaN         1             32900921925
# 928414  Ordinateur          NaN         1             32900921925
# 928415  Ordinateur          NaN         1             32900921925
# 928416  Ordinateur          NaN         1             32900921925
# 928417  Ordinateur          NaN         1             32900921925
# 928418  Ordinateur          NaN         1             32900921925
# 928419  Ordinateur          NaN         1             32900921925
# 928420  Ordinateur          NaN         1             32900921925
# 928421  Ordinateur          NaN         1             32900921925
# 928422  Ordinateur          NaN         1             32900921925
# 928423  Ordinateur          NaN         1             32900921925
# 928424  Ordinateur          NaN         1             32900921925
#
# [928425 rows x 12 columns]
